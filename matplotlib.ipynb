# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
areas=['marketing','sales','development','hr','customer support']
budget=[2.5,4,10,1,6]
plt.pie(budget,labels=areas,autopct="%0.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x14802249a90>,
#   <matplotlib.patches.Wedge at 0x14802249e50>,
#   <matplotlib.patches.Wedge at 0x1480224a210>,
#   <matplotlib.patches.Wedge at 0x1480224a5d0>,
#   <matplotlib.patches.Wedge at 0x1480224a990>],
#  [Text(1.0391359932945505, 0.3608273651481383, 'marketing'),
#   Text(0.39534842462775427, 1.026498720478673, 'sales'),
#   Text(-1.097543578735165, 0.07347171413004353, 'development'),
#   Text(-0.18296193275584066, -1.0846773396555527, 'hr'),
#   Text(0.7647118070885887, -0.7907059201114567, 'customer support')],
#  [Text(0.5668014508879367, 0.19681492644443907, '10.6%'),
#   Text(0.2156445952515023, 0.5599083929883671, '17.0%'),
#   Text(-0.5986601338555445, 0.04007548043456919, '42.6%'),
#   Text(-0.09979741786682217, -0.591642185266665, '4.3%'),
#   Text(0.4171155311392301, -0.4312941382426127, '25.5%')])

# %%
product_id=[1,2,3,4,5,6,7,8]
online_price=[233,456,770,120,222,444,200,300]
plt.plot(product_id,online_price,color='red',marker='D',markersize=20)

# %%
x=[23,45,12,49,97,32,11,44]
y=[45,34,67,87,55,22,89,90]
plt.scatter(x,y)
plt.xlabel('age')
plt.ylabel('salary')
plt.title('age vs salary graph')
# Out:
# Text(0.5, 1.0, 'age vs salary graph')
